# %%
# %pwd
# !git clone https://github.com/jaywalnut310/vits.git
# !git clone git@github.com:isi-nlp/uroman.git
# !python --version
# %cd vits/

# !pip install Cython==0.29.21
# !pip install librosa==0.8.0
# !pip install phonemizer==2.2.1
# !pip install scipy
# !pip install numpy==1.20.0
# !pip install torch
# !pip install torchvision
# !pip install matplotlib
# !pip install Unidecode==1.1.1
# !pip install numba==0.53.0

# %cd monotonic_align/
# %mkdir monotonic_align
# !python3 setup.py build_ext --inplace
# %cd ../
# %pwd
# Out:
# fatal: destination path 'vits' already exists and is not an empty directory.
# Python 3.9.18
# /nfs/datab/hungdx/TTS/MMS/vits
# /home/hungdx/miniconda3/envs/MMS-TTS/lib/python3.9/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
# Collecting Cython==0.29.21
#   Downloading Cython-0.29.21-cp39-cp39-manylinux1_x86_64.whl (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 2.4 MB/s eta 0:00:0000:0100:01
# Installing collected packages: Cython
# Successfully installed Cython-0.29.21
# Collecting librosa==0.8.0
#   Using cached librosa-0.8.0.tar.gz (183 kB)
#   Preparing metadata (setup.py) ... done
# Collecting audioread>=2.0.0 (from librosa==0.8.0)
#   Using cached audioread-3.0.1-py3-none-any.whl.metadata (8.4 kB)
# Collecting numpy>=1.15.0 (from librosa==0.8.0)
#   Using cached numpy-1.26.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Collecting scipy>=1.0.0 (from librosa==0.8.0)
#   Using cached scipy-1.11.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
# Collecting scikit-learn!=0.19.0,>=0.14.0 (from librosa==0.8.0)
#   Using cached scikit_learn-1.3.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting joblib>=0.14 (from librosa==0.8.0)
#   Using cached joblib-1.3.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: decorator>=3.0.0 in /home/hungdx/miniconda3/envs/MMS-TTS/lib/python3.9/site-packages (from librosa==0.8.0) (5.1.1)
# Collecting resampy>=0.2.2 (from librosa==0.8.0)
#   Using cached resampy-0.4.2-py3-none-any.whl (3.1 MB)
# Collecting numba>=0.43.0 (from librosa==0.8.0)
#   Using cached numba-0.58.1-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.7 kB)
# Collecting soundfile>=0.9.0 (from librosa==0.8.0)
#   Using cached soundfile-0.12.1-py2.py3-none-manylinux_2_31_x86_64.whl (1.2 MB)
# Collecting pooch>=1.0 (from librosa==0.8.0)
#   Using cached pooch-1.8.0-py3-none-any.whl.metadata (9.9 kB)
# Collecting llvmlite<0.42,>=0.41.0dev0 (from numba>=0.43.0->librosa==0.8.0)
#   Using cached llvmlite-0.41.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.8 kB)
# Requirement already satisfied: platformdirs>=2.5.0 in /home/hungdx/miniconda3/envs/MMS-TTS/lib/python3.9/site-packages (from pooch>=1.0->librosa==0.8.0) (4.1.0)
# Requirement already satisfied: packaging>=20.0 in /home/hungdx/miniconda3/envs/MMS-TTS/lib/python3.9/site-packages (from pooch>=1.0->librosa==0.8.0) (23.2)
# Collecting requests>=2.19.0 (from pooch>=1.0->librosa==0.8.0)
#   Using cached requests-2.31.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting threadpoolctl>=2.0.0 (from scikit-learn!=0.19.0,>=0.14.0->librosa==0.8.0)
#   Using cached threadpoolctl-3.2.0-py3-none-any.whl.metadata (10.0 kB)
# Collecting cffi>=1.0 (from soundfile>=0.9.0->librosa==0.8.0)
#   Using cached cffi-1.16.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting pycparser (from cffi>=1.0->soundfile>=0.9.0->librosa==0.8.0)
#   Using cached pycparser-2.21-py2.py3-none-any.whl (118 kB)
# Collecting charset-normalizer<4,>=2 (from requests>=2.19.0->pooch>=1.0->librosa==0.8.0)
#   Using cached charset_normalizer-3.3.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (33 kB)
# Collecting idna<4,>=2.5 (from requests>=2.19.0->pooch>=1.0->librosa==0.8.0)
#   Using cached idna-3.6-py3-none-any.whl.metadata (9.9 kB)
# Collecting urllib3<3,>=1.21.1 (from requests>=2.19.0->pooch>=1.0->librosa==0.8.0)
#   Using cached urllib3-2.1.0-py3-none-any.whl.metadata (6.4 kB)
# Collecting certifi>=2017.4.17 (from requests>=2.19.0->pooch>=1.0->librosa==0.8.0)
#   Using cached certifi-2023.11.17-py3-none-any.whl.metadata (2.2 kB)
# Using cached audioread-3.0.1-py3-none-any.whl (23 kB)
# Using cached joblib-1.3.2-py3-none-any.whl (302 kB)
# Using cached numba-0.58.1-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.6 MB)
# Using cached numpy-1.26.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
# Using cached pooch-1.8.0-py3-none-any.whl (62 kB)
# Using cached scikit_learn-1.3.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.9 MB)
# Using cached scipy-1.11.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (36.6 MB)
# Using cached cffi-1.16.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (443 kB)
# Using cached llvmlite-0.41.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (43.6 MB)
# Using cached requests-2.31.0-py3-none-any.whl (62 kB)
# Using cached threadpoolctl-3.2.0-py3-none-any.whl (15 kB)
# Using cached certifi-2023.11.17-py3-none-any.whl (162 kB)
# Using cached charset_normalizer-3.3.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (142 kB)
# Using cached idna-3.6-py3-none-any.whl (61 kB)
# Using cached urllib3-2.1.0-py3-none-any.whl (104 kB)
# Building wheels for collected packages: librosa
#   Building wheel for librosa (setup.py) ... done
#   Created wheel for librosa: filename=librosa-0.8.0-py3-none-any.whl size=201368 sha256=3827fa168afdf3c45e281485a654240769cb8ed53989a9053ff71320b7d54efd
#   Stored in directory: /home/hungdx/.cache/pip/wheels/a4/09/cc/728ed681f0fa5c37e0fbfc66d2ba07058dd995784f1f6554a8
# Successfully built librosa
# Installing collected packages: urllib3, threadpoolctl, pycparser, numpy, llvmlite, joblib, idna, charset-normalizer, certifi, audioread, scipy, requests, numba, cffi, soundfile, scikit-learn, resampy, pooch, librosa
# Successfully installed audioread-3.0.1 certifi-2023.11.17 cffi-1.16.0 charset-normalizer-3.3.2 idna-3.6 joblib-1.3.2 librosa-0.8.0 llvmlite-0.41.1 numba-0.58.1 numpy-1.26.2 pooch-1.8.0 pycparser-2.21 requests-2.31.0 resampy-0.4.2 scikit-learn-1.3.2 scipy-1.11.4 soundfile-0.12.1 threadpoolctl-3.2.0 urllib3-2.1.0
# Collecting phonemizer==2.2.1
#   Using cached phonemizer-2.2.1-py3-none-any.whl (49 kB)
# Requirement already satisfied: joblib in /home/hungdx/miniconda3/envs/MMS-TTS/lib/python3.9/site-packages (from phonemizer==2.2.1) (1.3.2)
# Collecting segments (from phonemizer==2.2.1)
#   Using cached segments-2.2.1-py2.py3-none-any.whl (15 kB)
# Collecting attrs>=18.1 (from phonemizer==2.2.1)
#   Using cached attrs-23.1.0-py3-none-any.whl (61 kB)
# Collecting clldutils>=1.7.3 (from segments->phonemizer==2.2.1)
#   Using cached clldutils-3.22.1-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting csvw>=1.5.6 (from segments->phonemizer==2.2.1)
#   Using cached csvw-3.2.1-py2.py3-none-any.whl.metadata (10 kB)
# Collecting regex (from segments->phonemizer==2.2.1)
#   Using cached regex-2023.10.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (40 kB)
# Requirement already satisfied: python-dateutil in /home/hungdx/miniconda3/envs/MMS-TTS/lib/python3.9/site-packages (from clldutils>=1.7.3->segments->phonemizer==2.2.1) (2.8.2)
# Collecting tabulate>=0.7.7 (from clldutils>=1.7.3->segments->phonemizer==2.2.1)
#   Using cached tabulate-0.9.0-py3-none-any.whl (35 kB)
# Collecting colorlog (from clldutils>=1.7.3->segments->phonemizer==2.2.1)
#   Using cached colorlog-6.8.0-py3-none-any.whl.metadata (10 kB)
# Collecting bibtexparser>=2.0.0b4 (from clldutils>=1.7.3->segments->phonemizer==2.2.1)
#   Using cached bibtexparser-2.0.0b4-py3-none-any.whl.metadata (5.6 kB)
# Collecting pylatexenc (from clldutils>=1.7.3->segments->phonemizer==2.2.1)
#   Using cached pylatexenc-2.10.tar.gz (162 kB)
#   Preparing metadata (setup.py) ... done
# Collecting markdown (from clldutils>=1.7.3->segments->phonemizer==2.2.1)
#   Using cached Markdown-3.5.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting lxml (from clldutils>=1.7.3->segments->phonemizer==2.2.1)
#   Downloading lxml-4.9.4-cp39-cp39-manylinux_2_28_x86_64.whl.metadata (3.7 kB)
# Collecting markupsafe (from clldutils>=1.7.3->segments->phonemizer==2.2.1)
#   Using cached MarkupSafe-2.1.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Collecting babel (from csvw>=1.5.6->segments->phonemizer==2.2.1)
#   Using cached Babel-2.14.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting colorama (from csvw>=1.5.6->segments->phonemizer==2.2.1)
#   Using cached colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Collecting isodate (from csvw>=1.5.6->segments->phonemizer==2.2.1)
#   Using cached isodate-0.6.1-py2.py3-none-any.whl (41 kB)
# Collecting jsonschema (from csvw>=1.5.6->segments->phonemizer==2.2.1)
#   Using cached jsonschema-4.20.0-py3-none-any.whl.metadata (8.1 kB)
# Collecting language-tags (from csvw>=1.5.6->segments->phonemizer==2.2.1)
#   Using cached language_tags-1.2.0-py3-none-any.whl (213 kB)
# Collecting rdflib (from csvw>=1.5.6->segments->phonemizer==2.2.1)
#   Using cached rdflib-7.0.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: requests in /home/hungdx/miniconda3/envs/MMS-TTS/lib/python3.9/site-packages (from csvw>=1.5.6->segments->phonemizer==2.2.1) (2.31.0)
# Collecting rfc3986<2 (from csvw>=1.5.6->segments->phonemizer==2.2.1)
#   Using cached rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Collecting uritemplate>=3.0.0 (from csvw>=1.5.6->segments->phonemizer==2.2.1)
#   Using cached uritemplate-4.1.1-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: six in /home/hungdx/miniconda3/envs/MMS-TTS/lib/python3.9/site-packages (from isodate->csvw>=1.5.6->segments->phonemizer==2.2.1) (1.16.0)
# Collecting jsonschema-specifications>=2023.03.6 (from jsonschema->csvw>=1.5.6->segments->phonemizer==2.2.1)
#   Using cached jsonschema_specifications-2023.11.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting referencing>=0.28.4 (from jsonschema->csvw>=1.5.6->segments->phonemizer==2.2.1)
#   Using cached referencing-0.32.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting rpds-py>=0.7.1 (from jsonschema->csvw>=1.5.6->segments->phonemizer==2.2.1)
#   Downloading rpds_py-0.15.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Requirement already satisfied: importlib-metadata>=4.4 in /home/hungdx/miniconda3/envs/MMS-TTS/lib/python3.9/site-packages (from markdown->clldutils>=1.7.3->segments->phonemizer==2.2.1) (7.0.0)
# Collecting pyparsing<4,>=2.1.0 (from rdflib->csvw>=1.5.6->segments->phonemizer==2.2.1)
#   Using cached pyparsing-3.1.1-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/hungdx/miniconda3/envs/MMS-TTS/lib/python3.9/site-packages (from requests->csvw>=1.5.6->segments->phonemizer==2.2.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/hungdx/miniconda3/envs/MMS-TTS/lib/python3.9/site-packages (from requests->csvw>=1.5.6->segments->phonemizer==2.2.1) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/hungdx/miniconda3/envs/MMS-TTS/lib/python3.9/site-packages (from requests->csvw>=1.5.6->segments->phonemizer==2.2.1) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/hungdx/miniconda3/envs/MMS-TTS/lib/python3.9/site-packages (from requests->csvw>=1.5.6->segments->phonemizer==2.2.1) (2023.11.17)
# Requirement already satisfied: zipp>=0.5 in /home/hungdx/miniconda3/envs/MMS-TTS/lib/python3.9/site-packages (from importlib-metadata>=4.4->markdown->clldutils>=1.7.3->segments->phonemizer==2.2.1) (3.17.0)
# Using cached clldutils-3.22.1-py2.py3-none-any.whl (1.7 MB)
# Using cached csvw-3.2.1-py2.py3-none-any.whl (56 kB)
# Using cached regex-2023.10.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (773 kB)
# Using cached bibtexparser-2.0.0b4-py3-none-any.whl (37 kB)
# Using cached Babel-2.14.0-py3-none-any.whl (11.0 MB)
# Using cached colorlog-6.8.0-py3-none-any.whl (11 kB)
# Using cached jsonschema-4.20.0-py3-none-any.whl (84 kB)
# Downloading lxml-4.9.4-cp39-cp39-manylinux_2_28_x86_64.whl (8.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 4.6 MB/s eta 0:00:0000:0100:01
# Using cached Markdown-3.5.1-py3-none-any.whl (102 kB)
# Using cached MarkupSafe-2.1.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Using cached rdflib-7.0.0-py3-none-any.whl (531 kB)
# Using cached jsonschema_specifications-2023.11.2-py3-none-any.whl (17 kB)
# Using cached pyparsing-3.1.1-py3-none-any.whl (103 kB)
# Using cached referencing-0.32.0-py3-none-any.whl (26 kB)
# Downloading rpds_py-0.15.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 3.5 MB/s eta 0:00:00a 0:00:01
# Building wheels for collected packages: pylatexenc
#   Building wheel for pylatexenc (setup.py) ... done
#   Created wheel for pylatexenc: filename=pylatexenc-2.10-py3-none-any.whl size=136816 sha256=7a69bdc1cf02b9373452c48103201b631b2c01911a7e6e1bda9061e899b60e26
#   Stored in directory: /home/hungdx/.cache/pip/wheels/a3/68/66/2f15abd0673d83c02f354115feedeb89c3daed2ac319b11090
# Successfully built pylatexenc
# Installing collected packages: rfc3986, pylatexenc, language-tags, uritemplate, tabulate, rpds-py, regex, pyparsing, markupsafe, lxml, isodate, colorlog, colorama, bibtexparser, babel, attrs, referencing, rdflib, markdown, jsonschema-specifications, clldutils, jsonschema, csvw, segments, phonemizer
# Successfully installed attrs-23.1.0 babel-2.14.0 bibtexparser-2.0.0b4 clldutils-3.22.1 colorama-0.4.6 colorlog-6.8.0 csvw-3.2.1 isodate-0.6.1 jsonschema-4.20.0 jsonschema-specifications-2023.11.2 language-tags-1.2.0 lxml-4.9.4 markdown-3.5.1 markupsafe-2.1.3 phonemizer-2.2.1 pylatexenc-2.10 pyparsing-3.1.1 rdflib-7.0.0 referencing-0.32.0 regex-2023.10.3 rfc3986-1.5.0 rpds-py-0.15.2 segments-2.2.1 tabulate-0.9.0 uritemplate-4.1.1
# Requirement already satisfied: scipy in /home/hungdx/miniconda3/envs/MMS-TTS/lib/python3.9/site-packages (1.11.4)
# Requirement already satisfied: numpy<1.28.0,>=1.21.6 in /home/hungdx/miniconda3/envs/MMS-TTS/lib/python3.9/site-packages (from scipy) (1.26.2)
# Requirement already satisfied: numpy in /home/hungdx/miniconda3/envs/MMS-TTS/lib/python3.9/site-packages (1.26.2)
# Collecting torch
#   Downloading torch-2.1.2-cp39-cp39-manylinux1_x86_64.whl.metadata (25 kB)
# Collecting filelock (from torch)
#   Using cached filelock-3.13.1-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: typing-extensions in /home/hungdx/miniconda3/envs/MMS-TTS/lib/python3.9/site-packages (from torch) (4.9.0)
# Collecting sympy (from torch)
#   Using cached sympy-1.12-py3-none-any.whl (5.7 MB)
# Collecting networkx (from torch)
#   Using cached networkx-3.2.1-py3-none-any.whl.metadata (5.2 kB)
# Collecting jinja2 (from torch)
#   Using cached Jinja2-3.1.2-py3-none-any.whl (133 kB)
# Collecting fsspec (from torch)
#   Using cached fsspec-2023.12.2-py3-none-any.whl.metadata (6.8 kB)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.18.1 (from torch)
#   Using cached nvidia_nccl_cu12-2.18.1-py3-none-manylinux1_x86_64.whl (209.8 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Collecting triton==2.1.0 (from torch)
#   Using cached triton-2.1.0-0-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.3 kB)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch)
#   Using cached nvidia_nvjitlink_cu12-12.3.101-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/hungdx/miniconda3/envs/MMS-TTS/lib/python3.9/site-packages (from jinja2->torch) (2.1.3)
# Collecting mpmath>=0.19 (from sympy->torch)
#   Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Downloading torch-2.1.2-cp39-cp39-manylinux1_x86_64.whl (670.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 670.2/670.2 MB 2.1 MB/s eta 0:00:0000:0100:05
# Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Using cached triton-2.1.0-0-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89.3 MB)
# Using cached filelock-3.13.1-py3-none-any.whl (11 kB)
# Using cached fsspec-2023.12.2-py3-none-any.whl (168 kB)
# Using cached networkx-3.2.1-py3-none-any.whl (1.6 MB)
# Using cached nvidia_nvjitlink_cu12-12.3.101-py3-none-manylinux1_x86_64.whl (20.5 MB)
# Installing collected packages: mpmath, sympy, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, networkx, jinja2, fsspec, filelock, triton, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torch
# Successfully installed filelock-3.13.1 fsspec-2023.12.2 jinja2-3.1.2 mpmath-1.3.0 networkx-3.2.1 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.18.1 nvidia-nvjitlink-cu12-12.3.101 nvidia-nvtx-cu12-12.1.105 sympy-1.12 torch-2.1.2 triton-2.1.0
# Collecting torchvision
#   Downloading torchvision-0.16.2-cp39-cp39-manylinux1_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: numpy in /home/hungdx/miniconda3/envs/MMS-TTS/lib/python3.9/site-packages (from torchvision) (1.26.2)
# Requirement already satisfied: requests in /home/hungdx/miniconda3/envs/MMS-TTS/lib/python3.9/site-packages (from torchvision) (2.31.0)
# Requirement already satisfied: torch==2.1.2 in /home/hungdx/miniconda3/envs/MMS-TTS/lib/python3.9/site-packages (from torchvision) (2.1.2)
# Collecting pillow!=8.3.*,>=5.3.0 (from torchvision)
#   Using cached Pillow-10.1.0-cp39-cp39-manylinux_2_28_x86_64.whl.metadata (9.5 kB)
# Requirement already satisfied: filelock in /home/hungdx/miniconda3/envs/MMS-TTS/lib/python3.9/site-packages (from torch==2.1.2->torchvision) (3.13.1)
# Requirement already satisfied: typing-extensions in /home/hungdx/miniconda3/envs/MMS-TTS/lib/python3.9/site-packages (from torch==2.1.2->torchvision) (4.9.0)
# Requirement already satisfied: sympy in /home/hungdx/miniconda3/envs/MMS-TTS/lib/python3.9/site-packages (from torch==2.1.2->torchvision) (1.12)
# Requirement already satisfied: networkx in /home/hungdx/miniconda3/envs/MMS-TTS/lib/python3.9/site-packages (from torch==2.1.2->torchvision) (3.2.1)
# Requirement already satisfied: jinja2 in /home/hungdx/miniconda3/envs/MMS-TTS/lib/python3.9/site-packages (from torch==2.1.2->torchvision) (3.1.2)
# Requirement already satisfied: fsspec in /home/hungdx/miniconda3/envs/MMS-TTS/lib/python3.9/site-packages (from torch==2.1.2->torchvision) (2023.12.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/hungdx/miniconda3/envs/MMS-TTS/lib/python3.9/site-packages (from torch==2.1.2->torchvision) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/hungdx/miniconda3/envs/MMS-TTS/lib/python3.9/site-packages (from torch==2.1.2->torchvision) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/hungdx/miniconda3/envs/MMS-TTS/lib/python3.9/site-packages (from torch==2.1.2->torchvision) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/hungdx/miniconda3/envs/MMS-TTS/lib/python3.9/site-packages (from torch==2.1.2->torchvision) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/hungdx/miniconda3/envs/MMS-TTS/lib/python3.9/site-packages (from torch==2.1.2->torchvision) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/hungdx/miniconda3/envs/MMS-TTS/lib/python3.9/site-packages (from torch==2.1.2->torchvision) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/hungdx/miniconda3/envs/MMS-TTS/lib/python3.9/site-packages (from torch==2.1.2->torchvision) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/hungdx/miniconda3/envs/MMS-TTS/lib/python3.9/site-packages (from torch==2.1.2->torchvision) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/hungdx/miniconda3/envs/MMS-TTS/lib/python3.9/site-packages (from torch==2.1.2->torchvision) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.18.1 in /home/hungdx/miniconda3/envs/MMS-TTS/lib/python3.9/site-packages (from torch==2.1.2->torchvision) (2.18.1)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/hungdx/miniconda3/envs/MMS-TTS/lib/python3.9/site-packages (from torch==2.1.2->torchvision) (12.1.105)
# Requirement already satisfied: triton==2.1.0 in /home/hungdx/miniconda3/envs/MMS-TTS/lib/python3.9/site-packages (from torch==2.1.2->torchvision) (2.1.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/hungdx/miniconda3/envs/MMS-TTS/lib/python3.9/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch==2.1.2->torchvision) (12.3.101)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/hungdx/miniconda3/envs/MMS-TTS/lib/python3.9/site-packages (from requests->torchvision) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/hungdx/miniconda3/envs/MMS-TTS/lib/python3.9/site-packages (from requests->torchvision) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/hungdx/miniconda3/envs/MMS-TTS/lib/python3.9/site-packages (from requests->torchvision) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/hungdx/miniconda3/envs/MMS-TTS/lib/python3.9/site-packages (from requests->torchvision) (2023.11.17)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/hungdx/miniconda3/envs/MMS-TTS/lib/python3.9/site-packages (from jinja2->torch==2.1.2->torchvision) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /home/hungdx/miniconda3/envs/MMS-TTS/lib/python3.9/site-packages (from sympy->torch==2.1.2->torchvision) (1.3.0)
# Downloading torchvision-0.16.2-cp39-cp39-manylinux1_x86_64.whl (6.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 4.5 MB/s eta 0:00:0000:0100:01
# Using cached Pillow-10.1.0-cp39-cp39-manylinux_2_28_x86_64.whl (3.6 MB)
# Installing collected packages: pillow, torchvision
# Successfully installed pillow-10.1.0 torchvision-0.16.2
# Collecting matplotlib
#   Downloading matplotlib-3.8.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.8 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Using cached contourpy-1.2.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.47.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (157 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 157.2/157.2 kB 1.6 MB/s eta 0:00:00a 0:00:01
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Using cached kiwisolver-1.4.5-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (6.4 kB)
# Requirement already satisfied: numpy<2,>=1.21 in /home/hungdx/miniconda3/envs/MMS-TTS/lib/python3.9/site-packages (from matplotlib) (1.26.2)
# Requirement already satisfied: packaging>=20.0 in /home/hungdx/miniconda3/envs/MMS-TTS/lib/python3.9/site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in /home/hungdx/miniconda3/envs/MMS-TTS/lib/python3.9/site-packages (from matplotlib) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/hungdx/miniconda3/envs/MMS-TTS/lib/python3.9/site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/hungdx/miniconda3/envs/MMS-TTS/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Collecting importlib-resources>=3.2.0 (from matplotlib)
#   Using cached importlib_resources-6.1.1-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: zipp>=3.1.0 in /home/hungdx/miniconda3/envs/MMS-TTS/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.17.0)
# Requirement already satisfied: six>=1.5 in /home/hungdx/miniconda3/envs/MMS-TTS/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Downloading matplotlib-3.8.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 3.5 MB/s eta 0:00:0000:0100:01
# Using cached contourpy-1.2.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (310 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.47.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 3.5 MB/s eta 0:00:0000:0100:01
# Using cached importlib_resources-6.1.1-py3-none-any.whl (33 kB)
# Using cached kiwisolver-1.4.5-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
# Installing collected packages: kiwisolver, importlib-resources, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.2.0 cycler-0.12.1 fonttools-4.47.0 importlib-resources-6.1.1 kiwisolver-1.4.5 matplotlib-3.8.2
# Collecting Unidecode==1.1.1
#   Using cached Unidecode-1.1.1-py2.py3-none-any.whl (238 kB)
# Installing collected packages: Unidecode
# Successfully installed Unidecode-1.1.1
# /nfs/datab/hungdx/TTS/MMS/vits/monotonic_align
# mkdir: cannot create directory ‘monotonic_align’: File exists
# core.c: In function ‘__Pyx_InitGlobals’:
# core.c:16766:1: warning: ‘PyEval_InitThreads’ is deprecated [-Wdeprecated-declarations]
# 16766 | PyEval_InitThreads();
#       | ^~~~~~~~~~~~~~~~~~
# In file included from /home/hungdx/miniconda3/envs/MMS-TTS/include/python3.9/Python.h:140,
#                  from core.c:16:
# /home/hungdx/miniconda3/envs/MMS-TTS/include/python3.9/ceval.h:130:37: note: declared here
#   130 | Py_DEPRECATED(3.9) PyAPI_FUNC(void) PyEval_InitThreads(void);
#       |                                     ^~~~~~~~~~~~~~~~~~
# /nfs/datab/hungdx/TTS/MMS/vits
# '/nfs/datab/hungdx/TTS/MMS/vits'
